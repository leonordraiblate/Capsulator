# %%
from capsulator_helper import *
import pandas as pd

# %%
random_pictures, picture_links=random_picture()

# %%
random_pictures
# Out:
#                                                    5  13 6  11 16 2  8  3  22
# Coats_Coat_Trench Coat_bege_No Pattern_NaN_NaN_...  0  0  0  0  0  0  0  0  0
# Top_Shirt_Sweater/Jumper_bege/black_Stripes_Woo...  0  0  0  0  0  0  0  0  0
# Bottom_Pants_Straight_white_No Pattern_Ganga_Na...  0  0  0  0  0  0  0  0  0
# Accessories_Bags_Bowler_black_No Pattern_NaN_Sm...  0  0  0  0  0  0  0  1  0
# Footwear_Shoes_Ballerinas_bege/black_No Pattern...  1  0  0  0  0  0  0  0  0
# ...                                                .. .. .. .. .. .. .. .. ..
# Top_Shirt_T-shirt_black_No Pattern_Cotton_NaN_S...  0  0  0  0  0  0  0  0  0
# Accessories_Bags_Tote_black_No Pattern_Leather_...  0  0  0  0  0  0  1  0  0
# Footwear_Sandals_High heels_black_No Pattern_Na...  0  0  0  0  0  0  1  0  0
# Coats_Coat_Jacket_black_No Pattern_Leather_Over...  0  0  0  0  0  0  0  0  0
# Top_Shirt_sweatshirt_white_No Pattern_Cotton_Ov...  0  0  0  0  0  0  0  0  0
#
# [101 rows x 9 columns]

# %%
picture_links
# Out:
#                                            image link
# 5   https://i.pinimg.com/564x/9e/84/54/9e8454d51d4...
# 13  https://i.pinimg.com/564x/3f/fc/77/3ffc7789056...
# 6   https://i.pinimg.com/564x/63/ee/99/63ee99a0bb8...
# 11  https://i.pinimg.com/750x/93/12/eb/9312ebd000d...
# 16  https://i.pinimg.com/564x/65/1b/d1/651bd12b874...
# 2   https://i.pinimg.com/564x/38/c1/56/38c156d6ffb...
# 8   https://i.pinimg.com/564x/cd/f3/89/cdf389695cc...
# 3   https://i.pinimg.com/564x/d7/b3/eb/d7b3ebb0100...
# 22  https://i.pinimg.com/564x/f7/1d/a7/f71da7733c4...

# %%
voting=votings(random_pictures,picture_links)
# Out:
# <img src="https://i.pinimg.com/564x/9e/84/54/9e8454d51d4f5fd3f6d16c9acdf82961.jpg"/>
# From 1 to 5, how much do you like this outfit?1
# <img src="https://i.pinimg.com/564x/3f/fc/77/3ffc778905661f2e959de45ea356ca09.jpg"/>
# From 1 to 5, how much do you like this outfit?2
# <img src="https://i.pinimg.com/564x/63/ee/99/63ee99a0bb8fbcf1bfe54c1bb1f10682.jpg"/>
# From 1 to 5, how much do you like this outfit?3
# <img src="https://i.pinimg.com/750x/93/12/eb/9312ebd000d0ba94ffe659e3f17ab85c.jpg"/>
# From 1 to 5, how much do you like this outfit?4
# <img src="https://i.pinimg.com/564x/65/1b/d1/651bd12b8741a60d0e7f8232f3e10001.jpg"/>
# From 1 to 5, how much do you like this outfit?5
# <img src="https://i.pinimg.com/564x/38/c1/56/38c156d6ffb01cf794b8791a87c2010c.jpg"/>
# From 1 to 5, how much do you like this outfit?1
# <img src="https://i.pinimg.com/564x/cd/f3/89/cdf389695ccb64cb5e23feb06a68f062.jpg"/>
# From 1 to 5, how much do you like this outfit?2
# ...

# %%
voting
# Out:
#    user_rating
# 5            1
# 13           2
# 6            3
# 11           4
# 16           5
# 2            1
# 8            2
# 3            3
# 22           4

# %%
user_preferences=ratings(random_pictures,voting)

# %%
user_preferences
# Out:
#                                                      Average
# Accessories_Bags_Bowler_black_No Pattern_NaN_Sm...  0.333333
# Footwear_Shoes_Ballerinas_bege/black_No Pattern...  0.111111
# Top_Shirt_T-shirt_white_No Pattern_Coton_Oversi...  0.555556
# Footwear_Shoes_Sneakers_white_No Pattern_NaN_Na...  1.222222
# Accessories_Bags_Bucket_white_No Pattern_NaN_Sm...  0.222222
# Accessories_Earrings_Hoop_NaN_NaN_Golden_Medium...  0.888889
# Accessories_Sunglasses_Wayfarer_NaN_NaN_NaN_Med...  1.222222
# Top_Shirt_Sleeveless_white_No Pattern_Cotton_Na...  0.444444
# Bottom_Pants_pegged_black_No Pattern_Cotton_NaN...  0.111111
# Accessories_Neckless_Choker_NaN_No Pattern_Gold...  0.444444
# Top_Shirt_Sweatshirt_Grey_No Pattern_Cotton_NaN...  0.444444
# Footwear_Shoes_Sneakers_black/white_No Pattern_...  0.333333
# Top_Coat_Blazer_bege_No Pattern_NaN_Oversized_W...  0.333333
# Accessories_Bags_Baguette_black_No Pattern_NaN_...  0.444444
# ...

# %%
recommended_clothes=recommended_clothes(user_preferences)
# Out:
# /Users/leonordraiblate/Documents/Ironhack/Course/Week 9/capsulator_helper.py:52: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   user_clothes = distances.loc[set(user_preferences.index),set(distances.columns).difference(set(user_preferences.index))]

# %%
Top, Bottom, Coats, Fullbody,Footwear,Accessories=recom_categ(recommended_clothes)
# Out:
# Dataframe for Category: Accessories
#     Rating                                               Item     Category  \
# 2        3  Accessories_Earrings_Stud_NaN_NaN_Pearl_Small_...  Accessories
# 15      16  Accessories_Bags_Bowler_brown_No Pattern_Leath...  Accessories
# 29      31  Accessories_Bags_Tote_brown_No Pattern_Leather...  Accessories
# 31      33  Accessories_Bags_Trapeze_NaN_No Pattern_Straw_...  Accessories
# 32      34  Accessories_Hats_Baseball Cap_black_No Pattern...  Accessories
#
#        Layer          Type  Color     Pattern Material   Size    Season  \
# 2   Earrings          Stud    NaN         NaN    Pearl  Small  All year
# 15      Bags        Bowler  brown  No Pattern  Leather  Small  All year
# 29      Bags          Tote  brown  No Pattern  Leather    NaN  All year
# 31      Bags       Trapeze    NaN  No Pattern    Straw  Large    Summer
# 32      Hats  Baseball Cap  black  No Pattern      NaN    NaN  All year
#
# ...

# %%
Top
# Out:
#     Rating                                               Item Category  Layer  \
# 0        1  Top_Shirt_Sweater/Jumper_bege_NaN_Wool_NaN_Winter      Top  Shirt
# 1        2  Top_Coat_Blazer_black_No Pattern_NaN_Oversized...      Top   Coat
# 3        4  Top_Shirt_Turtleneck_black_No Pattern_NaN_NaN_...      Top  Shirt
# 4        4  Top_Shirt_Turtleneck_black_No Pattern_NaN_NaN_...      Top  Shirt
# 5        5  Top_Coat_Blazer_grey_No Pattern_NaN_Oversized_...      Top   Coat
# 8        9  Top_Shirt_shirt_white_No Pattern_Cotton_NaN_Al...      Top  Shirt
# 10      11  Top_Shirt_Sweater/Jumper_white_NaN_Wool_NaN_Wi...      Top  Shirt
# 16      17  Top_Shirt_Sleeveless_black_No Pattern_Nan_NaN_...      Top  Shirt
# 18      19  Top_Shirt_Shirt_Blue_Stripes_Cotton_Oversized_...      Top  Shirt
# 20      21  Top_Shirt_Cardigan_grey_NaN_Wool_Oversized_Winter      Top  Shirt
# 21      23  Top_Shirt_Sweater/Jumper_bege/black_Stripes_Wo...      Top  Shirt
# ...
